# %%
import pandas as pd

# 엑셀 파일 읽기
excel_file = './data/남북한발전전력량.xlsx'  # 변환할 엑셀 파일 경로
df = pd.read_excel(excel_file)
print(df)

# CSV 파일로 저장
# csv_file = './data/nselec.csv'  # 저장할 CSV 파일 경로
# df.to_csv(csv_file, index=False, encoding='utf-8')
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
#1. 문제: 남한의 연도별 총 전력량(합계) 변화를 선 그래프로 그려라.
import pandas as pd

# 엑셀 파일 읽기
excel_file = './data/남북한발전전력량.xlsx'  # 변환할 엑셀 파일 경로
df = pd.read_excel(excel_file)
print(df.head())
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
from matplotlib import font_manager, rc
# 한글 폰트 설정 (맑은 고딕 사용)
font_path = "C:/Windows/Fonts/malgun.ttf"  # '맑은 고딕' 폰트 경로
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# 1.문제: 남한의 연도별 총전력량(합계) 변화를 선그래프 그리기
df_ns = df.iloc[[0], 3:] 

# 행 인덱스 변경
df_ns.index = ['남한발전량'] 
# print(df_ns.head())
df_graph = df_ns.T
df_graph.plot( title="남한 총발전량")
# Out:
# <Axes: title={'center': '남한 총발전량'}>

# %%
#2. 문제: 북한의 연도별 총 전력량(합계)을 막대 그래프로 그려라.
df_ns = df.iloc[[5], 3:] 

# 행 인덱스 변경
df_ns.index = ['북한발전량'] 
# print(df_ns.head())
df_graph = df_ns.T
df_graph.plot(kind='bar', title="북한 총발전량")
# Out:
# <Axes: title={'center': '북한 총발전량'}>

# %%
#3. 문제: 남한의 연도별 수력발전량 변화를 꺽은선 그래프로 그려라.
df_ns = df.iloc[[1], 3:] 

# 행 인덱스 변경
df_ns.index = ['남한 수력발전량'] 
# print(df_ns.head())
df_graph = df_ns.T
df_graph.plot(kind='line', title="남한 수수력 발전량")
# Out:
# <Axes: title={'center': '남한 수수력 발전량'}>

# %%
#4. 문제: 북한의 연도별 화력발전량 변화를 꺽은선 그래프로 그려라.
df_ns = df.iloc[[7], 3:] 

# 행 인덱스 변경
df_ns.index = ['북한 화력발전량'] 
# print(df_ns.head())
df_graph = df_ns.T
df_graph.plot(kind='bar', title="북한 화력 발전량")
# Out:
# <Axes: title={'center': '북한 화력 발전량'}>

# %%
#5. 문제: 남한의 화력과 원자력 발전량의 연도별 비교를 선그래프로 그려라.
df_ns = df.iloc[[2,3], 3:] 

# 행 인덱스 변경
df_ns.index = ['화력발전량','원자력'] 
# print(df_ns.head())
df_graph = df_ns.T
ax = df_graph.plot(kind='line' , title="남한 화력과 원자력발전량 년도별 비교")
ax.legend(title='발전종류')
